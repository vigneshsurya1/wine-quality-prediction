# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/winequality-red.csv', delimiter=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
columns=list(df.columns)
fig = plt.figure(figsize=(15, 45))
axs = fig.subplots(11, 2)
plt.subplots_adjust(hspace=.5)
for i in range(11):
  sns.boxplot(x=columns[i],data=df,ax= axs[i, 0])
  sns.scatterplot(x=columns[i], y='quality', data=df, hue='quality', ax=axs[i, 1])
plt.tight_layout()

# %%
def cap_data(df):
    for col in df.columns:
        print("capping the ",col)
        if (((df[col].dtype)=='float64') | ((df[col].dtype)=='int64')):
            percentiles = df[col].quantile([0.01,0.99]).values
            df[col][df[col] <= percentiles[0]] = percentiles[0]
            df[col][df[col] >= percentiles[1]] = percentiles[1]
        else:
            df[col]=df[col]
    return df

final_df=cap_data(df)
# Out:
# capping the  fixed acidity
# capping the  volatile acidity
# capping the  citric acid
# capping the  residual sugar
# capping the  chlorides
# capping the  free sulfur dioxide
# capping the  total sulfur dioxide
# capping the  density
# capping the  pH
# capping the  sulphates
# capping the  alcohol
# capping the  quality
# <ipython-input-3-d972840144d7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][df[col] <= percentiles[0]] = percentiles[0]
# <ipython-input-3-d972840144d7>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][df[col] >= percentiles[1]] = percentiles[1]
# ...

# %%
final_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.310069          0.526720     0.270365        2.504469
# std         1.697965          0.173733     0.193243        1.169339
# min         5.200000          0.190000     0.000000        1.400000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        13.300000          1.020000     0.700200        8.306000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.086768            15.811957             46.245779     0.996742
# std       0.040995            10.185029             31.810471     0.001830
# ...

# %%
corr=final_df.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr ,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-b064615515fb> in <cell line: 3>()
#       1 corr=final_df.corr()
#       2 plt.figure(figsize=(10,6))
# ----> 3 sns.heatmap(corr, annot=True, fmt='.2f', linewidth=0.5, cmap='green', mask=np.triu(corr))
#       4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     444     """
#     445     # Initialize the plotter object
# --> 446     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                           annot_kws, cbar, cbar_kws, xticklabels,
#     448                           yticklabels, mask)
#
# ...

# %%
final_df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8])

# %%
final_df=final_df.replace({
    'quality':{
        4:'bad',
        5:'good',
        6:'good',
        7:'best',
        8:'best'

    }
})

# %%
final_df['quality'].value_counts()
# Out:
# quality
# good    1319
# best     217
# bad       63
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
final_df['quality']=le.fit_transform(final_df['quality'])

# %%
x=final_df.drop('quality',axis=1)
y=final_df['quality']

# %%
x_new=pd.DataFrame(x)

# %%
x_new.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_new=ss.fit_transform(x_new)

# %%
x_new.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-069a9294ec1f> in <cell line: 1>()
# ----> 1 x_new.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
x_train, x_test, y_train, y_test = train_test_split(x_new, y, test_size = 0.2, random_state = 42,stratify=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1dce3a45376b> in <cell line: 1>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x_new, y, test_size = 0.2, random_state = 42,stratify=True)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2581         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2582
# -> 2583         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2584
#    2585     return list(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    2158         to an integer.
#    2159         """
# -> 2160         y = check_array(y, input_name="y", ensure_2d=False, dtype=None)
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)
